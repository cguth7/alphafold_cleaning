# %%
import pandas as pd

# %%
df = pd.read_parquet("final/final_panel_COMPLETE.parquet")

# %%
df[(df["n_veteran_papers"] >= 1)]
# Out:
#           gene_id    ym_x  year  month  quarter  year_quarter  bimonth  \
# 6               1  202007  2020      7        3         20203        4
# 8               1  202009  2020      9        3         20203        5
# 13              1  202102  2021      2        1         20211        1
# 14              1  202103  2021      3        1         20211        2
# 15              1  202104  2021      4        2         20212        2
# ...           ...     ...   ...    ...      ...           ...      ...
# 944286  112441434  202207  2022      7        3         20223        4
# 944287  112441434  202208  2022      8        3         20223        4
# 944288  112441434  202209  2022      9        3         20223        5
# 944291  112441434  202212  2022     12        4         20224        6
# 944295  112441434  202304  2023      4        2         20232        2
#
#         year_bimonth  n_papers  n_top25_y  ...  n_newcomer_papers  \
# ...

# %%
df
# Out:
#           gene_id      ym  year  month  quarter  year_quarter  bimonth  \
# 0               1  202001  2020      1        1         20201        1
# 1               1  202002  2020      2        1         20201        1
# 2               1  202003  2020      3        1         20201        2
# 3               1  202004  2020      4        2         20202        2
# 4               1  202005  2020      5        2         20202        3
# ...           ...     ...   ...    ...      ...           ...      ...
# 945115  122526777  202308  2023      8        3         20233        4
# 945116  122526777  202309  2023      9        3         20233        5
# 945117  122526777  202310  2023     10        4         20234        5
# 945118  122526777  202311  2023     11        4         20234        6
# 945119  122526777  202312  2023     12        4         20234        6
#
#         year_bimonth  n_papers  n_top25_y  ...  n_top05_b2  n_newcomer_papers  \
# ...

# %%
df
# Out:
#           gene_id    ym_x  year  month  quarter  year_quarter  bimonth  \
# 0               1  202001  2020      1        1         20201        1
# 1               1  202002  2020      2        1         20201        1
# 2               1  202003  2020      3        1         20201        2
# 3               1  202004  2020      4        2         20202        2
# 4               1  202005  2020      5        2         20202        3
# ...           ...     ...   ...    ...      ...           ...      ...
# 945115  122526777  202308  2023      8        3         20233        4
# 945116  122526777  202309  2023      9        3         20233        5
# 945117  122526777  202310  2023     10        4         20234        5
# 945118  122526777  202311  2023     11        4         20234        6
# 945119  122526777  202312  2023     12        4         20234        6
#
#         year_bimonth  n_papers  n_top25_y  ...  n_newcomer_papers  \
# ...
